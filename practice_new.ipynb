# %%
name = "rohit"
city = "noida"
age = 25
result = f"hi {name} you are from {city} and  your age is {age}"
print(result)
# Out:
# hi rohit you are from noida and  your age is 25

# %%
# \n
# \t
# \b
# \r
# \\
# \''

# %%
print("Hello\nPython")
# Out:
# Hello
# Python

# %%
print("Hello\tPython")
# Out:
# Hello	Python

# %%
print("Hello\bPython")
# Out:
# HellPython

# %%
print("Hello\rPython")
# Out:
# Python

# %%
print("Hello\\Python")
# Out:
# Hello\Python

# %%
import time
for i in range(1,15):
    time.sleep(0.5)
    print(i,end = "\r")
# Out:
# 14

# %%
print("hello ' Python'")
# Out:
# hello ' Python'

# %%
# string methods

# %%
# print()
# type()
# len()
# isinstance() etc

# %%
# Methods

# %%
string = "python"
string.capitalize()
# Out:
# 'Python'

# %%
string.center(40,'r')
# Out:
# 'rrrrrrrrrrrrrrrrrpythonrrrrrrrrrrrrrrrrr'

# %%
string.count()

# %%
text = "Hello world"
print(text.count("o",5,9))
# Out:
# 1

# %%
string.endswith("n")
# Out:
# True

# %%
string = input("create password only numbers and alpha:")

print(string.isalnum())
# Out:
# create password only numbers and alpha: xgsdgy266
# True
